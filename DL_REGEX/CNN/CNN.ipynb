# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
from tensorflow.keras import datasets,layers,models

# %% [markdown]
# load dataset

# %%
(train_images , train_labels) , (test_images , test_labels) =  datasets.cifar10.load_data()
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce so we will re-download the data.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#    303104/170498071 ━━━━━━━━━━━━━━━━━━━━ 6:41:55 142us/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 (train_images , train_labels) , (test_images , test_labels) =  datasets.cifar10.load_data()
#
# File c:\Users\ss\anaconda3\Lib\site-packages\keras\src\datasets\cifar10.py:70, in load_data()
#      68 dirname = "cifar-10-batches-py-target"
#      69 origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 70 path = get_file(
#      71     fname=dirname,
#      72     origin=origin,
#      73     extract=True,
#      74     file_hash=(  # noqa: E501
#      75         "6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce"
#      76     ),
#      77 )
#      79 num_train_samples = 50000
#      81 x_train = np.empty((num_train_samples, 3, 32, 32), dtype="uint8")
#
# File c:\Users\ss\anaconda3\Lib\site-packages\keras\src\utils\file_utils.py:395, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     393 try:
#     394     try:
# --> 395         urlretrieve(origin, download_target, DLProgbar())
#     396     except urllib.error.HTTPError as e:
#     397         raise Exception(error_msg.format(origin, e.code, e.msg))
#
# File c:\Users\ss\anaconda3\Lib\urllib\request.py:242, in urlretrieve(url, filename, reporthook, data)
#     239 if reporthook:
#     240     reporthook(blocknum, bs, size)
# --> 242 while block := fp.read(bs):
#     243     read += len(block)
#     244     tfp.write(block)
#
# File c:\Users\ss\anaconda3\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File c:\Users\ss\anaconda3\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File c:\Users\ss\anaconda3\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\ss\anaconda3\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
class_names = ['airplane' , 'automobile' , 'bird' , 'cat' , 'deer' , 'dog' , 'frog' , 'horse' , 'ship' , 'truck']

# %%
IMG_INDEX = 1
plt.imshow(train_images[IMG_INDEX],cmap = plt.cm.binary)
plt.xlabel(class_names[train_labels[IMG_INDEX][0]])
plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape = (32,32,3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64 , (3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3),activation='relu'))

# %%
model.summary()

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(10))

# %%
model.summary()

# %%
model.compile(optimizer = 'adam' , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics = ['accuracy'])

# %%
history = model.fit(train_images , train_labels,epochs = 10,validation_data = (test_images,test_labels))

# %%
# train on 50000 samples and validate on 10000 samples

# %%
# Evaluate the model  ===> we can determine hoe well the model performed by looking at its performace on the
# test data sets

# %%
test_loss,test_acc = model.evaluate(test_images,test_labels,verbose = 2)
print(test_acc)
