# %% [markdown]
# # NER --->

# %%
# Named Entity Recognition (NER) is an NLP technique used to find important names and information in
# text-such as people, places, organizations, dates, and amounts-and label them with their correct
# type.

# In Short:
# NER helps a machine understand "who", "what", and "where" from text.

# Example (Very Simple)
# Text:
# "Rohit Sharma lives in Mumbai."

# NER Output:
# Rohit Sharma -> PERSON
# Mumbai -> LOCATION (GPE)

# Why Do We Use NER?
# We use NER to convert unstructured text into meaningful, structured data.
# Main Reasons:
# Automatically extract important information
# Reduce manual work in reading documents
# Help machines understand context, not just keywords
# Make text usable for analytics, ML models, and databases

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting spacy
#   Downloading spacy-3.8.14-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp313-cp313-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp313-cp313-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\ss\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ss\anaconda3\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ss\anaconda3\lib\site-packages (from spacy) (2.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ss\anaconda3\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\ss\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\users\ss\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\ss\anaconda3\lib\site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ss\anaconda3\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ss\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\ss\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\ss\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ss\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ss\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ss\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ss\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.6.17)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: colorama in c:\users\ss\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ss\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading cloudpathlib-0.24.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open>=5.2.1 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading smart_open-8.0.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: httpx>=0.24.0 in c:\users\ss\anaconda3\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in c:\users\ss\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ss\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ss\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: wrapt in c:\users\ss\anaconda3\lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ss\anaconda3\lib\site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ss\anaconda3\lib\site-packages (from jinja2->spacy) (3.0.2)
# Downloading spacy-3.8.14-cp313-cp313-win_amd64.whl (14.2 MB)
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/14.2 MB 13.0 MB/s eta 0:00:01
#    ------------ --------------------------- 4.5/14.2 MB 12.2 MB/s eta 0:00:01
#    -------------------- ------------------- 7.3/14.2 MB 12.2 MB/s eta 0:00:01
#    --------------------------- ------------ 9.7/14.2 MB 12.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.6/14.2 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------  13.9/14.2 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------  14.2/14.2 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 14.2/14.2 MB 9.6 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp313-cp313-win_amd64.whl (40 kB)
# Downloading murmurhash-1.0.15-cp313-cp313-win_amd64.whl (25 kB)
# Downloading preshed-3.0.13-cp313-cp313-win_amd64.whl (122 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp313-cp313-win_amd64.whl (650 kB)
#    ---------------------------------------- 0.0/650.8 kB ? eta -:--:--
#    ---------------------------------------- 650.8/650.8 kB 3.8 MB/s eta 0:00:00
# Downloading thinc-8.3.13-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 7.3 MB/s eta 0:00:00
# Downloading blis-1.3.3-cp313-cp313-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------------- -------------------------- 2.1/6.2 MB 12.1 MB/s eta 0:00:01
#    --------------------------- ------------ 4.2/6.2 MB 11.1 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 10.5 MB/s eta 0:00:00
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.24.0-py3-none-any.whl (63 kB)
# Downloading smart_open-8.0.0-py3-none-any.whl (73 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, smart-open, murmurhash, cymem, confection, cloudpathlib, catalogue, blis, srsly, preshed, weasel, thinc, spacy
#
#    ----------------------------------------  0/15 [wasabi]
#    -- -------------------------------------  1/15 [spacy-loggers]
#    ----- ----------------------------------  2/15 [spacy-legacy]
#    -------- -------------------------------  3/15 [smart-open]
#    ---------------- -----------------------  6/15 [confection]
#    ------------------ ---------------------  7/15 [cloudpathlib]
#    --------------------- ------------------  8/15 [catalogue]
#    ------------------------ ---------------  9/15 [blis]
#    -------------------------- ------------- 10/15 [srsly]
#    -------------------------- ------------- 10/15 [srsly]
#    -------------------------- ------------- 10/15 [srsly]
#    -------------------------- ------------- 10/15 [srsly]
#    -------------------------- ------------- 10/15 [srsly]
#    -------------------------- ------------- 10/15 [srsly]
#    -------------------------- ------------- 10/15 [srsly]
#    -------------------------- ------------- 10/15 [srsly]
#    -------------------------- ------------- 10/15 [srsly]
#    -------------------------- ------------- 10/15 [srsly]
#    ----------------------------- ---------- 11/15 [preshed]
#    -------------------------------- ------- 12/15 [weasel]
#    ---------------------------------- ----- 13/15 [thinc]
#    ---------------------------------- ----- 13/15 [thinc]
#    ---------------------------------- ----- 13/15 [thinc]
#    ---------------------------------- ----- 13/15 [thinc]
#    ---------------------------------- ----- 13/15 [thinc]
#    ---------------------------------- ----- 13/15 [thinc]
#    ---------------------------------- ----- 13/15 [thinc]
#    ---------------------------------- ----- 13/15 [thinc]
#    ---------------------------------- ----- 13/15 [thinc]
#    ---------------------------------- ----- 13/15 [thinc]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ------------------------------------- -- 14/15 [spacy]
#    ---------------------------------------- 15/15 [spacy]
#
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.24.0 confection-1.3.3 cymem-2.0.13 murmurhash-1.0.15 preshed-3.0.13 smart-open-8.0.0 spacy-3.8.14 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 wasabi-1.1.3 weasel-1.0.0
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---- ----------------------------------- 1.3/12.8 MB 8.6 MB/s eta 0:00:02
#      --------- ------------------------------ 3.1/12.8 MB 8.6 MB/s eta 0:00:02
#      -------------- ------------------------- 4.7/12.8 MB 8.1 MB/s eta 0:00:01
#      ------------------- -------------------- 6.3/12.8 MB 8.0 MB/s eta 0:00:01
#      ------------------------ --------------- 7.9/12.8 MB 8.1 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 8.5 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 8.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
